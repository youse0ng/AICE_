# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
from matplotlib import font_manager, rc
font_path = "c:\WINDOWS\Fonts\GULIM.TTC"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
plt.rc('font', size=8)

# %%
plt.figure()
plt.plot([2017,2018,2019,2020,2021], [2732568,5262777,9735362,17334238,25678335],color='red')
plt.bar([2017,2018,2019,2020,2021], [2732568,5262777,9735362,17334238,25678335],color='blue')
plt.scatter([2017,2018,2019,2020,2021], [2732568,5262777,9735362,17334238,25678335],color='red')
plt.xlabel('년도')
plt.legend(['온라인 음식 서비스 거래액 (단위 :백만원)'])
plt.ylabel('온라인 음식서비스 거래액 (단위: 백만원)')
# Out:
# Text(0, 0.5, '온라인 음식서비스 거래액 (단위: 백만원)')
